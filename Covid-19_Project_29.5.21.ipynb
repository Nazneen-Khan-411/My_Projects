# %% [markdown]
# # WORLD VACCINATION IN COVID - 19

# %% [markdown]
# # Vaccinations Progress

# %% [markdown]
# The dataset contains the following information:
#
# 1) Country - this is the country for which the vaccination information is provided;
#
# 2) Country ISO Code - ISO code for the country;
#
# 3) Date- date for the data entry; for some of the dates we have only the daily vaccinations, for others, only the (cumulative) total;
#
# 4) Total number of vaccinations - this is the absolute number of total immunizations in the country;
#
# 5) Total number of people vaccinated - a person, depending on the immunization scheme, will receive one or more (typically 2) vaccines; at a certain moment, the number of vaccination might be larger than the number of people;
#
# 6) Total number of people fully vaccinated - this is the number of people that received the entire set of immunization according to the immunization scheme (typically 2); at a certain moment in time, there might be a certain number of people that received one vaccine and another number (smaller) of people that received all vaccines in the scheme;
#
# 7) Daily vaccinations (raw) - for a certain data entry, the number of vaccination for that date/country;
#
# 8) Total vaccinations per hundred - ratio (in percent) between vaccination number and total population up to the date in the country;
#
# 9) Total number of people vaccinated per hundred - ratio (in percent) between population immunized and total population up to the date in the country;
#
# 10) Total number of people fully vaccinated per hundred - ratio (in percent) between population fully immunized and total population up to the date in the country;
#
# 11) Number of vaccinations per day - number of daily vaccination for that day and country;
#
# 12) Daily vaccinations per million - ratio (in ppm) between vaccination number and total population for the current date in the country;
#
# 13) Vaccines used in the country - total number of vaccines used in the country (up to date);
#
# 14) Source name - source of the information (national authority, international organization, local organization etc.);
#
# 15) Source website - website of the source of information;

# %% [markdown]
# # Import Libraries

# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Import the Dataset

# %%
df=pd.read_csv(r'C:\Data Science\data set\country_vaccinations.csv')

# %% [markdown]
# # Check the Rows and Columns of Dataset

# %%
df.shape
# Out:
# (20390, 15)

# %%
df.dtypes
# Out:
# country                                 object
# iso_code                                object
# date                                    object
# total_vaccinations                     float64
# people_vaccinated                      float64
# people_fully_vaccinated                float64
# daily_vaccinations_raw                 float64
# daily_vaccinations                     float64
# total_vaccinations_per_hundred         float64
# people_vaccinated_per_hundred          float64
# people_fully_vaccinated_per_hundred    float64
# daily_vaccinations_per_million         float64
# vaccines                                object
# source_name                             object
# source_website                          object
# dtype: object

# %% [markdown]
# # Knowing the Dataset

# %%
df.head(50)
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 0   Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1   Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2   Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3   Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4   Afghanistan      AFG  2021-02-26                 NaN                NaN
# 5   Afghanistan      AFG  2021-02-27                 NaN                NaN
# 6   Afghanistan      AFG  2021-02-28              8200.0             8200.0
# 7   Afghanistan      AFG  2021-03-01                 NaN                NaN
# 8   Afghanistan      AFG  2021-03-02                 NaN                NaN
# 9   Afghanistan      AFG  2021-03-03                 NaN                NaN
# 10  Afghanistan      AFG  2021-03-04                 NaN                NaN
# ...

# %%
df.tail(50)
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 20340  Zimbabwe      ZWE  2021-04-05            145510.0           123454.0
# 20341  Zimbabwe      ZWE  2021-04-06            162633.0           139133.0
# 20342  Zimbabwe      ZWE  2021-04-07            179417.0           153238.0
# 20343  Zimbabwe      ZWE  2021-04-08            193677.0           166543.0
# 20344  Zimbabwe      ZWE  2021-04-09            206205.0           178237.0
# 20345  Zimbabwe      ZWE  2021-04-10            222733.0           193936.0
# 20346  Zimbabwe      ZWE  2021-04-11            223492.0           194594.0
# 20347  Zimbabwe      ZWE  2021-04-12            234579.0           205275.0
# 20348  Zimbabwe      ZWE  2021-04-13            248355.0           218516.0
# 20349  Zimbabwe      ZWE  2021-04-14            262128.0           231632.0
# 20350  Zimbabwe      ZWE  2021-04-15            285881.0           252932.0
# ...

# %%
df.iloc[1:20390:100]
# Out:
#                  country  iso_code        date  total_vaccinations  \
# 1            Afghanistan       AFG  2021-02-23                 NaN
# 101              Albania       ALB  2021-01-19               483.0
# 201              Albania       ALB  2021-04-29            453248.0
# 301              Andorra       AND  2021-03-18                 NaN
# 401               Angola       AGO  2021-04-09                 NaN
# ...                  ...       ...         ...                 ...
# 19901          Venezuela       VEN  2021-03-11                 NaN
# 20001            Vietnam       VNM  2021-04-06             53953.0
# 20101              Wales  OWID_WLS  2021-03-01           1045201.0
# 20201  Wallis and Futuna       WLF  2021-04-06                 NaN
# 20301           Zimbabwe       ZWE  2021-02-25             11007.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 1                    NaN                      NaN                     NaN
# ...

# %% [markdown]
# # Discover & visualize the data to gain insights

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20390 entries, 0 to 20389
# Data columns (total 15 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   country                              20390 non-null  object
#  1   iso_code                             20390 non-null  object
#  2   date                                 20390 non-null  object
#  3   total_vaccinations                   11618 non-null  float64
#  4   people_vaccinated                    10859 non-null  float64
#  5   people_fully_vaccinated              8386 non-null   float64
#  6   daily_vaccinations_raw               9671 non-null   float64
#  7   daily_vaccinations                   20176 non-null  float64
#  8   total_vaccinations_per_hundred       11618 non-null  float64
#  9   people_vaccinated_per_hundred        10859 non-null  float64
#  10  people_fully_vaccinated_per_hundred  8386 non-null   float64
# ...

# %%
df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        1.161800e+04       1.085900e+04             8.386000e+03
# mean         6.643173e+06       3.851860e+06             2.083977e+06
# std          2.907510e+07       1.433558e+07             8.919696e+06
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          7.506375e+04       6.298100e+04             2.849625e+04
# 50%          5.378870e+05       4.160840e+05             2.217265e+05
# 75%          2.516747e+06       1.740671e+06             8.917640e+05
# max          5.467140e+08       1.643783e+08             1.310786e+08
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            9.671000e+03        2.017600e+04
# mean             1.608349e+05        8.486205e+04
# std              7.718760e+05        4.911053e+05
# min              0.000000e+00        0.000000e+00
# 25%              3.404500e+03        8.160000e+02
# ...

# %%
df.describe().transpose()
# Out:
#                                        count          mean           std  min  \
# total_vaccinations                   11618.0  6.643173e+06  2.907510e+07  0.0
# people_vaccinated                    10859.0  3.851860e+06  1.433558e+07  0.0
# people_fully_vaccinated               8386.0  2.083977e+06  8.919696e+06  1.0
# daily_vaccinations_raw                9671.0  1.608349e+05  7.718760e+05  0.0
# daily_vaccinations                   20176.0  8.486205e+04  4.911053e+05  0.0
# total_vaccinations_per_hundred       11618.0  1.934177e+01  2.656694e+01  0.0
# people_vaccinated_per_hundred        10859.0  1.362960e+01  1.701790e+01  0.0
# people_fully_vaccinated_per_hundred   8386.0  7.365014e+00  1.140774e+01  0.0
# daily_vaccinations_per_million       20176.0  3.142786e+03  4.609730e+03  0.0
#
#                                           25%        50%           75%  \
# total_vaccinations                   75063.75  537887.00  2.516747e+06
# ...

# %% [markdown]
# # Look for any missing values

# %%
df.isna().any()
# Out:
# country                                False
# iso_code                               False
# date                                   False
# total_vaccinations                      True
# people_vaccinated                       True
# people_fully_vaccinated                 True
# daily_vaccinations_raw                  True
# daily_vaccinations                      True
# total_vaccinations_per_hundred          True
# people_vaccinated_per_hundred           True
# people_fully_vaccinated_per_hundred     True
# daily_vaccinations_per_million          True
# vaccines                               False
# source_name                            False
# source_website                         False
# dtype: bool

# %%
df.isna().sum()
# Out:
# country                                    0
# iso_code                                   0
# date                                       0
# total_vaccinations                      8772
# people_vaccinated                       9531
# people_fully_vaccinated                12004
# daily_vaccinations_raw                 10719
# daily_vaccinations                       214
# total_vaccinations_per_hundred          8772
# people_vaccinated_per_hundred           9531
# people_fully_vaccinated_per_hundred    12004
# daily_vaccinations_per_million           214
# vaccines                                   0
# source_name                                0
# source_website                             0
# dtype: int64

# %%
df.mean()
# Out:
# total_vaccinations                     6.643173e+06
# people_vaccinated                      3.851860e+06
# people_fully_vaccinated                2.083977e+06
# daily_vaccinations_raw                 1.608349e+05
# daily_vaccinations                     8.486205e+04
# total_vaccinations_per_hundred         1.934177e+01
# people_vaccinated_per_hundred          1.362960e+01
# people_fully_vaccinated_per_hundred    7.365014e+00
# daily_vaccinations_per_million         3.142786e+03
# dtype: float64

# %% [markdown]
# # Fill null values

# %%
df1=df.fillna(df.mean())

# %%
df1.head(50)
# Out:
#         country iso_code        date  total_vaccinations  people_vaccinated  \
# 0   Afghanistan      AFG  2021-02-22        0.000000e+00       0.000000e+00
# 1   Afghanistan      AFG  2021-02-23        6.643173e+06       3.851860e+06
# 2   Afghanistan      AFG  2021-02-24        6.643173e+06       3.851860e+06
# 3   Afghanistan      AFG  2021-02-25        6.643173e+06       3.851860e+06
# 4   Afghanistan      AFG  2021-02-26        6.643173e+06       3.851860e+06
# 5   Afghanistan      AFG  2021-02-27        6.643173e+06       3.851860e+06
# 6   Afghanistan      AFG  2021-02-28        8.200000e+03       8.200000e+03
# 7   Afghanistan      AFG  2021-03-01        6.643173e+06       3.851860e+06
# 8   Afghanistan      AFG  2021-03-02        6.643173e+06       3.851860e+06
# 9   Afghanistan      AFG  2021-03-03        6.643173e+06       3.851860e+06
# 10  Afghanistan      AFG  2021-03-04        6.643173e+06       3.851860e+06
# ...

# %%
df1.isnull().sum()
# Out:
# country                                0
# iso_code                               0
# date                                   0
# total_vaccinations                     0
# people_vaccinated                      0
# people_fully_vaccinated                0
# daily_vaccinations_raw                 0
# daily_vaccinations                     0
# total_vaccinations_per_hundred         0
# people_vaccinated_per_hundred          0
# people_fully_vaccinated_per_hundred    0
# daily_vaccinations_per_million         0
# vaccines                               0
# source_name                            0
# source_website                         0
# dtype: int64

# %% [markdown]
# # Find the correlations and visualized

# %%
sns.heatmap(df1.corr(), annot = True,  cmap="YlGnBu")
plt.show()

# %% [markdown]
# # Check the columns of Dataset

# %%
df1.columns
# Out:
# Index(['country', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred', 'daily_vaccinations_per_million',
#        'vaccines', 'source_name', 'source_website'],
#       dtype='object')

# %% [markdown]
# # Vaccine types

# %%
x=df1.vaccines.unique()
y= list(x)
for i in y : print(i)
# Out:
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V
# Sputnik V
# Oxford/AstraZeneca, Pfizer/BioNTech
# Oxford/AstraZeneca
# Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
# Oxford/AstraZeneca, Sinovac, Sputnik V
# Pfizer/BioNTech
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V
# Oxford/AstraZeneca, Sinopharm/Beijing
# Oxford/AstraZeneca, Sinovac
# Moderna, Pfizer/BioNTech
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac
# Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech
# Covaxin, Oxford/AstraZeneca
# Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac
# Covaxin, Oxford/AstraZeneca, Sinopharm/Beijing
# Moderna, Oxford/AstraZeneca, Sinopharm/Beijing, Sputnik V
# Abdala, Soberana02
# Oxford/AstraZeneca, Sinopharm/Beijing, Sinovac, Sputnik V
# Sinopharm/Beijing
# Oxford/AstraZeneca, Sputnik V
# ...

# %% [markdown]
# # Most Common Vaccines

# %%
df1.vaccines.value_counts()
# Out:
# Oxford/AstraZeneca                                                                    3574
# Johnson&Johnson, Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                         2919
# Moderna, Oxford/AstraZeneca, Pfizer/BioNTech                                          1600
# Oxford/AstraZeneca, Pfizer/BioNTech                                                   1569
# Moderna, Pfizer/BioNTech                                                              1231
# Pfizer/BioNTech                                                                       1188
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac                                          1003
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing, Sputnik V                      879
# Oxford/AstraZeneca, Sinopharm/Beijing                                                  835
# Oxford/AstraZeneca, Pfizer/BioNTech, Sinopharm/Beijing                                 395
# ...

# %%
from collections import OrderedDict

# %%
plt.figure(figsize=(16,16))
sns.countplot(y='vaccines',data=df1)
plt.ylabel('vaccines')
plt.xlabel('count')
plt.show()

# %% [markdown]
# # List of covid vaccine's

# %%
display(pd.DataFrame([df1['vaccines'].unique()], index=['Vaccine']).T.sort_values('Vaccine')\
          .style.set_caption('Vaccine names') )
# Out:
# <style  type="text/css" >
# </style><table id="T_9af252d4_c2fc_11eb_8bcc_c8e26540463c" ><caption>Vaccine names</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Vaccine</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9af252d4_c2fc_11eb_8bcc_c8e26540463clevel0_row0" class="row_heading level0 row0" >20</th>
#                         <td id="T_9af252d4_c2fc_11eb_8bcc_c8e26540463crow0_col0" class="data row0 col0" >Abdala, Soberana02</td>
#             </tr>
#             <tr>
#                         <th id="T_9af252d4_c2fc_11eb_8bcc_c8e26540463clevel0_row1" class="row_heading level0 row1" >33</th>
#                         <td id="T_9af252d4_c2fc_11eb_8bcc_c8e26540463crow1_col0" class="data row1 col0" >CanSino, Oxford/AstraZeneca, Pfizer/BioNTech, Sinovac, Sputnik V</td>
#             </tr>
#             <tr>
# ...

# %%
vaccines= df1.groupby(['country', 'vaccines']).count().reset_index()[['country', 'vaccines']]\
                  .groupby('vaccines').count()['country'].reset_index().sort_values('country', ascending=False)
vaccines.columns = ['Vaccines', 'Number of countries used']
display(vaccines.style.set_caption('Number of countries used vaccine'))
# Out:
# <style  type="text/css" >
# </style><table id="T_9af7ab9b_c2fc_11eb_96e8_c8e26540463c" ><caption>Number of countries used vaccine</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Vaccines</th>        <th class="col_heading level0 col1" >Number of countries used</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9af7ab9b_c2fc_11eb_96e8_c8e26540463clevel0_row0" class="row_heading level0 row0" >19</th>
#                         <td id="T_9af7ab9b_c2fc_11eb_96e8_c8e26540463crow0_col0" class="data row0 col0" >Oxford/AstraZeneca</td>
#                         <td id="T_9af7ab9b_c2fc_11eb_96e8_c8e26540463crow0_col1" class="data row0 col1" >54</td>
#             </tr>
#             <tr>
#                         <th id="T_9af7ab9b_c2fc_11eb_96e8_c8e26540463clevel0_row1" class="row_heading level0 row1" >9</th>
# ...

# %% [markdown]
# # Which countries have the most number of total vaccinated ?

# %%
plt.figure(figsize=(20, 6))
df1.groupby('country')['total_vaccinations'].max().sort_values(ascending=False)[:50].plot(kind='bar');
plt.title('Country vs Total Vaccination', fontsize=24, fontweight='bold')
plt.ylabel('Total Vaccinations');

# %% [markdown]
# # People Vaccinated

# %% [markdown]
# Idividuals who received at least the first dose of the vaccine

# %%
plt.figure(figsize=(20, 6))
df1.groupby('country')['people_vaccinated'].max().sort_values(ascending=False)[:50].plot(kind='bar');
plt.title('Country vs people_vaccinated', fontsize=24, fontweight='bold')
plt.ylabel('people_vaccinated');

# %% [markdown]
# # Countries leading in total number of fully vaccinated people

# %%
plt.figure(figsize=(20, 6))
data = df1.groupby('country')['people_fully_vaccinated'].max().sort_values(ascending=False)[:50]
plt.bar(data.index, data);
plt.xticks(rotation='90')
plt.yticks()
plt.title('Country vs People fully Vaccinated', fontsize=24, fontweight='bold')
plt.ylabel('people fully vaccinated');

# %% [markdown]
# # Countries with best daily average vaccinations

# %%
df1.groupby(['country']).agg({'daily_vaccinations':'mean'}).sort_values(by='daily_vaccinations', ascending=False)[:20].plot.barh(color="blue", figsize=(15,5))
plt.title('Average daily vaccinations by country - Top 10')
plt.legend('')
plt.xlabel('average daily vaccinations')
plt.show()

# %% [markdown]
# # People Vaccinated per 100

# %% [markdown]
# The number of people who received the vaccine per 100

# %%
plt.figure(figsize=(20, 6))
data = df1.groupby('country')['total_vaccinations_per_hundred'].max().sort_values(ascending=False)[:30]
plt.bar(data.index, data);
plt.xticks(rotation='90')
plt.yticks()
plt.title('Country vs total_vaccinations_per_hundred', fontsize=24, fontweight='bold')
plt.ylabel('total_vaccinations_per_hundred');

# %% [markdown]
# # Daily Vaccinations per million top countries

# %%
plt.figure(figsize=(20, 6))
data = df1.groupby('country')['daily_vaccinations_per_million'].max().sort_values(ascending=False)[:30]
plt.bar(data.index, data);
plt.xticks(rotation='90')
plt.yticks()
plt.title('Country vs daily_vaccinations_per_million', fontsize=24, fontweight='bold')
plt.ylabel('daily_vaccinations_per_million');

# %%
plt.figure(figsize= (8, 5))


ax = sns.barplot(data= df1, x= 'total_vaccinations', y= 'country',
           order= df1.sort_values('total_vaccinations')['country'][:10],
            palette= 'GnBu_r')

plt.title('Minors Vaccinations per Country')
plt.xlabel('Total Vaccinations')
plt.ylabel('Country')

for patch in ax.patches:
    width = patch.get_width()
    height = patch.get_height()
    x = patch.get_x()
    y = patch.get_y()
    
    plt.text(width + x, height + y, '{}'.format(int(width)))

# %%
df1[df1['total_vaccinations']==df1['total_vaccinations'].max()]
# Out:
#      country iso_code        date  total_vaccinations  people_vaccinated  \
# 3747   China      CHN  2021-05-25         546714000.0       3.851860e+06
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 3747             2.083977e+06              19461000.0          15860714.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 3747                           37.98                      13.629598
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million  \
# 3747                             7.365014                         11020.0
#
#                                          vaccines                 source_name  \
# 3747  Sinopharm/Beijing, Sinopharm/Wuhan, Sinovac  National Health Commission
#
#                                          source_website
# 3747  http://www.nhc.gov.cn/xcs/yqjzqk/202105/993e4d...

# %%
df1[df1['total_vaccinations']==df1['total_vaccinations'].min()]
# Out:
#            country iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 92         Albania      ALB  2021-01-10                 0.0
# 227        Algeria      DZA  2021-01-29                 0.0
# 362         Angola      AGO  2021-03-01                 0.0
# 444       Anguilla      AIA  2021-02-04                 0.0
# ...            ...      ...         ...                 ...
# 19823   Uzbekistan      UZB  2021-03-31                 0.0
# 19879    Venezuela      VEN  2021-02-17                 0.0
# 19971      Vietnam      VNM  2021-03-07                 0.0
# 20252       Zambia      ZMB  2021-04-14                 0.0
# 20294     Zimbabwe      ZWE  2021-02-18                 0.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0           0.000000e+00             2.083977e+06           160834.939303
# 92          0.000000e+00             2.083977e+06           160834.939303
# ...

# %% [markdown]
# # Covid 19 vaccinations INDIA

# %% [markdown]
#  Sorting out india's Data from the complete dataset

# %%
india_case=df1[df1['country']=='India']

# %%
india_case.head()
# Out:
#      country iso_code        date  total_vaccinations  people_vaccinated  \
# 8291   India      IND  2021-01-15                 0.0                0.0
# 8292   India      IND  2021-01-16            191181.0           191181.0
# 8293   India      IND  2021-01-17            224301.0           224301.0
# 8294   India      IND  2021-01-18            454049.0           454049.0
# 8295   India      IND  2021-01-19            674835.0           674835.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 8291             2.083977e+06           160834.939303        84862.052439
# 8292             2.083977e+06           191181.000000       191181.000000
# 8293             2.083977e+06            33120.000000       112150.000000
# 8294             2.083977e+06           229748.000000       151350.000000
# 8295             2.083977e+06           220786.000000       168709.000000
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
india_case.tail()
# Out:
#      country iso_code        date  total_vaccinations  people_vaccinated  \
# 8417   India      IND  2021-05-21        6.643173e+06       3.851860e+06
# 8418   India      IND  2021-05-22        1.908425e+08       1.492196e+08
# 8419   India      IND  2021-05-23        1.917192e+08       1.500332e+08
# 8420   India      IND  2021-05-24        1.941657e+08       1.523015e+08
# 8421   India      IND  2021-05-25        1.955068e+08       1.535114e+08
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 8417             2.083977e+06            1.608349e+05           1388325.0
# 8418             4.162288e+07            1.608349e+05           1328280.0
# 8419             4.168605e+07            8.767430e+05           1352605.0
# 8420             4.186421e+07            2.446471e+06           1478358.0
# 8421             4.199540e+07            1.341068e+06           1473597.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %% [markdown]
# # Name of vaccines used in INDIA

# %%
pd.DataFrame([india_case['vaccines'].unique()],columns=['Vaccine'],index=['India'])
# Out:
#                            Vaccine
# India  Covaxin, Oxford/AstraZeneca

# %% [markdown]
# # Total vaccinations in India last 5 days

# %%
india_last_5_days=india_case.tail()

# %%
india_last_5_days
# Out:
#      country iso_code        date  total_vaccinations  people_vaccinated  \
# 8417   India      IND  2021-05-21        6.643173e+06       3.851860e+06
# 8418   India      IND  2021-05-22        1.908425e+08       1.492196e+08
# 8419   India      IND  2021-05-23        1.917192e+08       1.500332e+08
# 8420   India      IND  2021-05-24        1.941657e+08       1.523015e+08
# 8421   India      IND  2021-05-25        1.955068e+08       1.535114e+08
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 8417             2.083977e+06            1.608349e+05           1388325.0
# 8418             4.162288e+07            1.608349e+05           1328280.0
# 8419             4.168605e+07            8.767430e+05           1352605.0
# 8420             4.186421e+07            2.446471e+06           1478358.0
# 8421             4.199540e+07            1.341068e+06           1473597.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# ...

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.lineplot(x='date',y='total_vaccinations',data=india_case)
plt.show()

# %%
last_day_vaccinations=df1[df1['date']=='2021-05-24']
last_day_vaccinations
# Out:
#                  country  iso_code        date  total_vaccinations  \
# 91           Afghanistan       AFG  2021-05-24        5.732770e+05
# 226              Albania       ALB  2021-05-24        7.251350e+05
# 788            Argentina       ARG  2021-05-24        1.114947e+07
# 893                Aruba       ABW  2021-05-24        1.097560e+05
# 993            Australia       AUS  2021-05-24        3.613053e+06
# ...                  ...       ...         ...                 ...
# 19877         Uzbekistan       UZB  2021-05-24        6.643173e+06
# 20185              Wales  OWID_WLS  2021-05-24        3.124549e+06
# 20249  Wallis and Futuna       WLF  2021-05-24        6.643173e+06
# 20292             Zambia       ZMB  2021-05-24        6.643173e+06
# 20389           Zimbabwe       ZWE  2021-05-24        9.149210e+05
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 91          4.763670e+05             9.691000e+04           160834.939303
# ...

# %% [markdown]
# # Prepare the data for machine learning algorithems

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(df1.drop(['total_vaccinations','iso_code','country','vaccines','source_name','date','source_website'],axis = 1),
                                                    df1['total_vaccinations'],
                                                    test_size = 0.30,
                                                    random_state = 30)

# %%
x_train
# Out:
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 15244       1.094976e+06             6.675690e+05            30074.000000
# 17320       6.328740e+05             3.368000e+05             3068.000000
# 14071       2.477300e+04             1.985000e+03             1312.000000
# 10203       6.646000e+03             2.083977e+06              305.000000
# 9441        1.129687e+06             5.609050e+05           160834.939303
# ...                  ...                      ...                     ...
# 500         3.851860e+06             2.083977e+06           160834.939303
# 12077       3.851860e+06             2.083977e+06           160834.939303
# 15277       1.082940e+05             2.083977e+06             5993.000000
# 4517        3.603600e+04             2.083977e+06             7942.000000
# 5925        4.260000e+03             3.808000e+03           160834.939303
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# ...

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
accuracy = model.score(x_test, y_test)
print(accuracy*100,'%')
# Out:
# 93.70077556292547 %

# %%
model.predict(x_test)
# Out:
# array([5056966.68826704,  977235.94133167, 1474868.17342837, ...,
#        4504498.10619204, 4901364.44773827, 1570833.29618701])
